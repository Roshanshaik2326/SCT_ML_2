# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %%
# Load the uploaded file
df = pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Check shape and info
print("Shape of data:", df.shape)
print("\nData types:\n", df.dtypes)
# Out:
# Shape of data: (200, 5)
#
# Data types:
#  CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
# Check for missing values
print("\nMissing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plot the Elbow graph
plt.figure(figsize=(8,5))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method to Find Optimal Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
# Apply KMeans with optimal clusters (e.g., 5)
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', palette='tab10')
plt.title('Customer Segments (2D View)')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
import plotly.express as px
df['Cluster'] = df['Cluster'].astype(str)

# Interactive 3D scatter plot
fig = px.scatter_3d(
    df,
    x='Age',
    y='Annual Income (k$)',
    z='Spending Score (1-100)',
    color='Cluster',
    title='3D Customer Segmentation (Interactive)',
    opacity=0.8
)

fig.update_layout(
    scene=dict(
        xaxis_title='Age',
        yaxis_title='Annual Income (k$)',
        zaxis_title='Spending Score (1-100)'
    ),
    width=900,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3247cdc7-c524-4432-b37d-8a64c33f8dce" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3247cdc7-c524-4432-b37d-8a64c33f8dce")) {                    Plotly.newPlot(                        "3247cdc7-c524-4432-b37d-8a64c33f8dce",                        [{"hovertemplate":"Cluster=2\u003cbr\u003eAge=%{x}\u003cbr\u003eAnnual Income (k$)=%{y}\u003cbr\u003eSpending Score (1-100)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"2","scene":"scene","showlegend":true,"x":[19,21,23,22,23,30,35,24,22,20,35,25,31,29,35,23,21,18,21,30,20,24,31,24,33,19,18,19,21],"y":[15,15,16,17,18,19,19,20,20,21,23,24,25,28,28,29,30,33,33,34,37,38,39,39,42,46,48,48,54],"z":[39,81,77,76,94,72,99,77,79,66,98,73,73,82,61,87,73,92,81,73,75,92,61,65,60,55,59,59,57],"type":"scatter3d"},{"hovertemplate":"Cluster=0\u003cbr\u003eAge=%{x}\u003cbr\u003eAnnual Income (k$)=%{y}\u003cbr\u003eSpending Score (1-100)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#EF553B","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"0","scene":"scene","showlegend":true,"x":[20,31,35,64,67,58,37,35,52,35,46,54,45,40,60,53,49,42,36,65,48,49,50,27,29,31,49,31,59,50,47,51,69,27,53,70,67,54,63,43,68,32,70,47,60,60,59,26,45,40,23,49,57,38,67,46,48,55,22,34,50,68,18,48,40,32,24,47,27,48,20,23,49,67,49,21,66,54,68,66,65,38,19,18,63,49,51,50,38],"y":[16,17,18,19,19,20,20,21,23,24,25,28,28,29,30,33,33,34,37,38,39,39,40,40,40,40,42,43,43,43,43,44,44,46,46,46,47,47,48,48,48,48,49,49,50,50,54,54,54,54,54,54,54,54,54,54,54,57,57,58,58,59,59,60,60,60,60,60,60,61,61,62,62,62,62,62,63,63,63,63,63,64,64,65,65,65,67,67,67],"z":[6,40,6,3,14,15,13,35,29,35,5,14,32,31,4,4,14,17,26,35,36,28,55,47,42,42,52,54,60,45,41,50,46,51,46,56,52,59,51,50,48,47,55,42,49,56,47,54,53,48,52,42,51,55,41,44,46,58,55,60,46,55,41,49,40,42,52,47,50,42,49,41,48,59,56,42,50,46,43,48,52,42,46,48,43,59,43,57,40],"type":"scatter3d"},{"hovertemplate":"Cluster=4\u003cbr\u003eAge=%{x}\u003cbr\u003eAnnual Income (k$)=%{y}\u003cbr\u003eSpending Score (1-100)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#00cc96","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"4","scene":"scene","showlegend":true,"x":[26,19,19,27,40,39,31,40,38,39,31,29,32,35,32,32,28,32,34,39,38,27,30,30,29,31,36,33,32,28,36,30,27],"y":[62,63,65,67,69,69,70,71,71,71,72,73,73,74,75,76,77,77,78,78,78,78,78,78,79,81,85,86,87,87,87,88,88],"z":[55,54,50,56,58,91,77,95,75,75,71,88,73,72,93,87,97,74,90,88,76,89,78,73,83,93,75,95,63,75,92,86,69],"type":"scatter3d"},{"hovertemplate":"Cluster=3\u003cbr\u003eAge=%{x}\u003cbr\u003eAnnual Income (k$)=%{y}\u003cbr\u003eSpending Score (1-100)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#ab63fa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"3","scene":"scene","showlegend":true,"x":[23,43,59,47,25,20,44,19,57,28,25,48,34,43,44,47,37,34,56,19,50,42,36,40,36,52,58,59,37,46,41,54,41,34,33,47,45,32],"y":[70,71,71,71,72,73,73,74,75,76,77,77,78,78,78,78,78,78,79,81,85,86,87,87,87,88,88,93,97,98,99,101,103,103,113,120,126,137],"z":[29,35,11,9,34,5,7,10,5,40,12,36,22,17,20,16,1,1,35,5,26,20,27,13,10,13,15,14,32,15,39,24,17,23,8,16,28,18],"type":"scatter3d"},{"hovertemplate":"Cluster=1\u003cbr\u003eAge=%{x}\u003cbr\u003eAnnual Income (k$)=%{y}\u003cbr\u003eSpending Score (1-100)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#FFA15A","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"1","scene":"scene","showlegend":true,"x":[35,32,29,30,28,36,32,38,35,32,30], ...

# %%
df[['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)', 'Cluster']].head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100) Cluster
# 0           1    Male   19                  15                      39       2
# 1           2    Male   21                  15                      81       2
# 2           3  Female   20                  16                       6       0
# 3           4  Female   23                  16                      77       2
# 4           5  Female   31                  17                      40       0
